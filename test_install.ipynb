# %% [markdown]
# # 21M.387 Fundamentals of Music Processing
# ## Installation Test
#
# Click on a cell and press _Control Enter_ to run the python code in that cell.
#
# The code cells below should run without error if you installed all the necessary components.

# %%
import numpy as np
import scipy
from ipywidgets import interact
import matplotlib.pyplot as plt
import IPython.display as ipd
import requests
import hmmlearn
import sys

if (sys.version_info.major, sys.version_info.minor) != (3,9):
    print('Error. You are running the wrong python version. Please change it to 3.9')

# %%
plt.figure()
plt.plot(np.random.random(100))
ipd.Audio(url="https://www.kozco.com/tech/piano2.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="https://www.kozco.com/tech/piano2.wav" type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
@interact(a=(1,10))
def foo(a):
    print(a ** 2)
# Out:
# interactive(children=(IntSlider(value=5, description='a', max=10, min=1), Output()), _dom_classes=('widget-int…

# %% [markdown]
# Note: you should see a slider generated for the above code cell that lets you change the values of `a`. If you don't see that, try running this on the command line:
#
# `jupyter nbextension enable --py widgetsnbextension`
